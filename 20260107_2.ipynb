# %% [markdown]
# <a href="https://colab.research.google.com/github/MunSu2001/File/blob/main/20260107_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

# %%
data = sys.stdin.readline()

# %%
n = int(input())
# Out:
#  4

# %% [markdown]
# ```
# 4
# Baha enter
# Askar enter
# Baha leave
# Artem enter
# ```

# %%
list_check = []
for _ in range(n):
    name, check = input().split()
    if check == 'enter':
        list_check.append(name)
    else:
        list_check.remove(name)
# Out:
#  Baha enter
#  Askar enter
#  Baha leave
#  Artem enter

# %%
list_check.sort(reverse=True)

# %%
for name in list_check:
    print(name)
# Out:
# Askar
# Artem

# %%
name, check = data.split()

# %%
a = ['a', 'b', 'c']

# %%
a.index('b')
# Out:
# 1

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
help(a.remove)
# Out:
# Help on built-in function remove:
#
# remove(value, /) method of builtins.list instance
#     Remove first occurrence of value.
#
#     Raises ValueError if the value is not present.

# %%
a.remove('b')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 a.remove('b')
#
# ValueError: list.remove(x): x not in list

# %%
a
# Out:
# ['a']

# %%
Baha enter
Askar enter
Baha leave
Artem enter

# %%
n = int(input())
list_check = dict()
for _ in range(n):
    name, check = input().split()
    if check == 'enter':
        list_check[name] = 1
    else:
        del list_check[name]

for name, _ in sorted(list_check.items(), key=lambda x : x[0], reverse=True):
    print(name)
# Out:
#  4
#  Baha enter
#  Askar enter
#  Baha leave
#  Artem enter
# Artem
# Askar

# %%
dict_1 = {'a' : 4, 'b' : 3, 'c' :5}

# %%
del dict_1['a']

# %%
dict_1
# Out:
# {}

# %%
dict_1 = {'a' : 4, 'b' : 3, 'c' :5}

# %%
sorted(dict_1.items(), key=lambda x : x[1])
# Out:
# [('b', 3), ('a', 4), ('c', 5)]

# %%
dict_1 = {'aa' : 4, 'ab' : 3, 'ac' :5}

# %%
for x, _ in sorted(dict_1.items(), key=lambda x : x[0]):
    print(x)
# Out:
# aa
# ab
# ac

# %%
'201107' > '20260101'
# Out:
# False

# %%
hex(ord('A'))
# Out:
# '0x41'

# %%
import pandas as pd

# %%
# 데이터 전처리
# preprocessing
# 목적 -> 데이터 수집(DB, 외부사이트)  -> 전처리 ->  모델 학습 (분류, 예측)
#help(pd.read_csv)
kbo_df= pd.read_csv("./kbo.csv")

# %%
kbo_df.shape
# Out:
# (870, 11)

# %%
kbo_df.loc[ 1 , '경력']
# Out:
# '태전초(경기광주시리틀)-모가중-야로고BC-동원대'

# %%
kbo_df.iloc[1, 5]
# Out:
# '태전초(경기광주시리틀)-모가중-야로고BC-동원대'

# %%
height = int("188cm/88kg".split('/')[0].replace("cm", ""))

# %%
weight = int("188cm/88kg".split('/')[1].replace("kg", ""))

# %%
round(weight / (height/100)**2,2)
# Out:
# 24.9

# %%
#None, nan
# ''
kbo_df['신장/체중'].isnull().sum()
# Out:
# 0

# %%
kbo_df[kbo_df['신장/체중'].apply(lambda x : len(x) < 5)]
# Out:
# Empty DataFrame
# Columns: [선수명, 등번호, 생년월일, 포지션, 신장/체중, 경력, 입단 계약금, 연봉, 지명순위, 입단년도, Team]
# Index: []

# %%
kbo_df['신장'] = kbo_df['신장/체중'].apply(lambda x : x.split('/')[0].replace("cm", ""))

# %%
kbo_df = kbo_df[kbo_df['신장'] != ''].copy()

# %%
kbo_df['신장'] = kbo_df['신장'].astype(int)

# %%
kbo_df['체중'] = kbo_df['신장/체중'].apply(lambda x : int(x.split('/')[1].replace("kg", "")) )

# %%
kbo_df['bmi'] = kbo_df['체중'] / (kbo_df['신장'] / 100) ** 2

# %%
kbo_df.sort_values(by=['bmi'], ascending=False).tail()
# Out:
#      선수명     등번호           생년월일        포지션       신장/체중  \
# 456  성지훈   No.57  2000년 01월 29일   투수(좌투좌타)  181cm/68kg
# 462  엄상백   No.11  1996년 10월 04일   투수(우언우타)  187cm/72kg
# 227  이태규   No.45  2000년 02월 21일   투수(우투좌타)  188cm/72kg
# 36   백선기  No.114  1998년 08월 27일   투수(좌투좌타)  186cm/70kg
# 254  강한울    No.6  1991년 09월 12일  내야수(우투좌타)  181cm/66kg
#
#                              경력   입단 계약금       연봉                 지명순위   입단년도  \
# 456          송정동초-무등중-광주제일고-동아대      NaN   3000만원           23 한화 육성선수   24한화
# 462        역삼초-언북중-덕수고-KT-상무-KT  23000만원  90000만원             15 KT 1차   15KT
# 227            희망대초-매향중-장안고-KIA   8000만원   3000만원  19 KIA 2차 3라운드 30순위  23KIA
# 36             남도초-경상중-대구상원고-KT   5000만원   3000만원   18 KT 2차 7라운드 61순위    NaN
# 254  사당초-중앙중-안산공고-원광대-KIA-삼성-상무  14000만원   7000만원   14 KIA 2차 1라운드 5순위  14KIA
#
#         Team   신장  체중        bmi
# 456   한화 이글스  181  68  20.756387
# 462   한화 이글스  187  72  20.589665
# 227    KT 위즈  188  72  20.371209
# ...

# %%
import re

p = re.compile("[0-9]+")
list(map(int,p.findall("188cm/88kgl")))
# Out:
# [188, 88]
